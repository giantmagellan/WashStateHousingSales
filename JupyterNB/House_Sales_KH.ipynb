# %%
import pandas as pd
import numpy as np

# %%
house_sales = pd.read_csv("/Users/katiehu/Downloads/Dataset 2 (House Sales)/house_sales.csv")

# %%
house_sales.shape
# Out:
# (21613, 21)

# %%
house_sales.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
house_sales
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0       3.0       1.00
# 1      6414100192  20141209T000000  538000.0       3.0       2.25
# 2      5631500400  20150225T000000  180000.0       2.0       1.00
# 3      2487200875  20141209T000000  604000.0       4.0       3.00
# 4      1954400510  20150218T000000  510000.0       3.0       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0       3.0       2.50
# 21609  6600060120  20150223T000000  400000.0       4.0       2.50
# 21610  1523300141  20140623T000000  402101.0       2.0       0.75
# 21611   291310100  20150116T000000  400000.0       3.0       2.50
# 21612  1523300157  20141015T000000  325000.0       2.0       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0           1180.0    5650.0     1.0           0     0  ...      7
# ...

# %%
sub_house_sales = house_sales.loc[:,['id','price','sqft_living','zipcode']]
sub_house_sales
# Out:
#                id     price  sqft_living  zipcode
# 0      7129300520  221900.0       1180.0    98178
# 1      6414100192  538000.0       2570.0    98125
# 2      5631500400  180000.0        770.0    98028
# 3      2487200875  604000.0       1960.0    98136
# 4      1954400510  510000.0       1680.0    98074
# ...           ...       ...          ...      ...
# 21608   263000018  360000.0       1530.0    98103
# 21609  6600060120  400000.0       2310.0    98146
# 21610  1523300141  402101.0       1020.0    98144
# 21611   291310100  400000.0       1600.0    98027
# 21612  1523300157  325000.0       1020.0    98144
#
# [21613 rows x 4 columns]

# %%
house_sales.isnull().sum() #count the number of missing rows by column
# Out:
# id                  0
# date                0
# price               0
# bedrooms         1134
# bathrooms        1068
# sqft_living      1110
# sqft_lot         1044
# floors              0
# waterfront          0
# view                0
# condition           0
# grade               0
# sqft_above          0
# sqft_basement       0
# yr_built            0
# yr_renovated        0
# zipcode             0
# lat                 0
# long                0
# sqft_living15       0
# sqft_lot15          0
# dtype: int64

# %%
house_sales[house_sales['bedrooms'].isnull()]
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 18       16000397  20141205T000000   189000.0       NaN       1.00
# 23     8091400200  20140516T000000   252700.0       NaN       1.50
# 31     2426039314  20141201T000000   280000.0       NaN       1.50
# 32      461000390  20140624T000000   687500.0       NaN       1.75
# 46     8945200830  20150325T000000   210490.0       NaN       1.00
# ...           ...              ...        ...       ...        ...
# 21498  1972200555  20140714T000000   610000.0       NaN       1.75
# 21505  9468200109  20140617T000000  1555000.0       NaN       3.50
# 21523  3304300300  20150507T000000   579950.0       NaN       2.75
# 21565  5007500120  20150226T000000   341780.0       NaN       2.75
# 21577  3881900317  20150123T000000   579000.0       NaN       3.25
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 18          1200.0    9850.0     1.0           0     0  ...      7
# ...

# %%
house_sales.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  20479.000000  20545.000000  20503.000000
# mean   4.580302e+09  5.400881e+05      3.372821      2.113507   2081.073697
# std    2.876566e+09  3.671272e+05      0.930711      0.768913    915.043176
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.500000   1430.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1920.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  12050.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.056900e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.517982e+04      1.494309      0.007542      0.234303      3.409430
# ...
