# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Import .csv file
house_sales = pd.read_csv("/Users/katiehu/Downloads/Dataset 2 (House Sales)/house_sales.csv")

# %%
house_sales.shape #Shape to see number of rows and columns there are
# Out:
# (21613, 21)

# %%
house_sales.columns #Listed Columns in Data set
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
house_sales #Preview of the Data
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0       3.0       1.00
# 1      6414100192  20141209T000000  538000.0       3.0       2.25
# 2      5631500400  20150225T000000  180000.0       2.0       1.00
# 3      2487200875  20141209T000000  604000.0       4.0       3.00
# 4      1954400510  20150218T000000  510000.0       3.0       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0       3.0       2.50
# 21609  6600060120  20150223T000000  400000.0       4.0       2.50
# 21610  1523300141  20140623T000000  402101.0       2.0       0.75
# 21611   291310100  20150116T000000  400000.0       3.0       2.50
# 21612  1523300157  20141015T000000  325000.0       2.0       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0           1180.0    5650.0     1.0           0     0  ...      7
# 1           2570.0    7242.0     2.0           0     0  ...      7
# 2            770.0   10000.0     1.0           0     0  ...      6
# 3           1960.0    5000.0     1.0           0     0  ...      7
# 4           1680.0    8080.0     1.0           0     0  ...      8
# ...            ...       ...     ...         ...   ...  ...    ...
# 21608       1530.0    1131.0     3.0           0     0  ...      8
# 21609       2310.0    5813.0     2.0           0     0  ...      8
# 21610       1020.0    1350.0     2.0           0     0  ...      7
# 21611       1600.0    2388.0     2.0           0     0  ...      8
# 21612       1020.0    1076.0     2.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 0            1180              0      1955             0    98178  47.5112
# 1            2170            400      1951          1991    98125  47.7210
# 2             770              0      1933             0    98028  47.7379
# 3            1050            910      1965             0    98136  47.5208
# 4            1680              0      1987             0    98074  47.6168
# ...           ...            ...       ...           ...      ...      ...
# 21608        1530              0      2009             0    98103  47.6993
# 21609        2310              0      2014             0    98146  47.5107
# 21610        1020              0      2009             0    98144  47.5944
# 21611        1600              0      2004             0    98027  47.5345
# 21612        1020              0      2008             0    98144  47.5941
#
#           long  sqft_living15  sqft_lot15
# 0     -122.257           1340        5650
# 1     -122.319           1690        7639
# 2     -122.233           2720        8062
# 3     -122.393           1360        5000
# 4     -122.045           1800        7503
# ...        ...            ...         ...
# 21608 -122.346           1530        1509
# 21609 -122.362           1830        7200
# 21610 -122.299           1020        2007
# 21611 -122.069           1410        1287
# 21612 -122.299           1020        1357
#
# [21613 rows x 21 columns]

# %%
house_sales.describe() #Descriptive Analysis
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  20479.000000  20545.000000  20503.000000
# mean   4.580302e+09  5.400881e+05      3.372821      2.113507   2081.073697
# std    2.876566e+09  3.671272e+05      0.930711      0.768913    915.043176
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.500000   1430.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1920.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  12050.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.056900e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.517982e+04      1.494309      0.007542      0.234303      3.409430
# std    4.148617e+04      0.539989      0.086517      0.766318      0.650743
# min    5.200000e+02      1.000000      0.000000      0.000000      1.000000
# 25%    5.040000e+03      1.000000      0.000000      0.000000      3.000000
# 50%    7.620000e+03      1.500000      0.000000      0.000000      3.000000
# 75%    1.070800e+04      2.000000      0.000000      0.000000      4.000000
# max    1.651359e+06      3.500000      1.000000      4.000000      5.000000
#
#               grade    sqft_above  sqft_basement      yr_built  yr_renovated  \
# count  21613.000000  21613.000000   21613.000000  21613.000000  21613.000000
# mean       7.656873   1788.390691     291.509045   1971.005136     84.402258
# std        1.175459    828.090978     442.575043     29.373411    401.679240
# min        1.000000    290.000000       0.000000   1900.000000      0.000000
# 25%        7.000000   1190.000000       0.000000   1951.000000      0.000000
# 50%        7.000000   1560.000000       0.000000   1975.000000      0.000000
# 75%        8.000000   2210.000000     560.000000   1997.000000      0.000000
# max       13.000000   9410.000000    4820.000000   2015.000000   2015.000000
#
#             zipcode           lat          long  sqft_living15     sqft_lot15
# count  21613.000000  21613.000000  21613.000000   21613.000000   21613.000000
# mean   98077.939805     47.560053   -122.213896    1986.552492   12768.455652
# std       53.505026      0.138564      0.140828     685.391304   27304.179631
# min    98001.000000     47.155900   -122.519000     399.000000     651.000000
# 25%    98033.000000     47.471000   -122.328000    1490.000000    5100.000000
# 50%    98065.000000     47.571800   -122.230000    1840.000000    7620.000000
# 75%    98118.000000     47.678000   -122.125000    2360.000000   10083.000000
# max    98199.000000     47.777600   -121.315000    6210.000000  871200.000000

# %%
house_sales.isnull().sum() #Count the number of missing rows by column
# Out:
# id                  0
# date                0
# price               0
# bedrooms         1134
# bathrooms        1068
# sqft_living      1110
# sqft_lot         1044
# floors              0
# waterfront          0
# view                0
# condition           0
# grade               0
# sqft_above          0
# sqft_basement       0
# yr_built            0
# yr_renovated        0
# zipcode             0
# lat                 0
# long                0
# sqft_living15       0
# sqft_lot15          0
# dtype: int64

# %%
house_sales.dtypes #Data Types
# Out:
# id                 int64
# date              object
# price            float64
# bedrooms         float64
# bathrooms        float64
# sqft_living      float64
# sqft_lot         float64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %%
''' Create new dataframe to preserve original dataset and assign to new variable '''
house_clean = pd.DataFrame(data=house_sales)     
dates = house_clean["date"]
dates.head()
# Out:
# 0    20141013T000000
# 1    20141209T000000
# 2    20150225T000000
# 3    20141209T000000
# 4    20150218T000000
# Name: date, dtype: object

# %%
''' Strip 'T000000' from date column and insert into housing sales dataframe '''
house_clean['date'] = pd.Series([date.strip('T000000') for date in dates], index=house_clean.index)
house_clean['date'].head()
# Out:
# 0    20141013
# 1    20141209
# 2    20150225
# 3    20141209
# 4    20150218
# Name: date, dtype: object

# %%
#Find Missing Values of sqft_living with new dataframe#
#Take Sum of sqft_above + sqft_basement.

sqft_living_total = house_clean['sqft_above'] + house_clean['sqft_basement']
house_clean['sqft_living'] = house_clean['sqft_living'].fillna(sqft_living_total, axis=0)

# %%
#Find Missing Values of sqft_lot
house_clean['sqft_lot'] = round(house_clean['sqft_lot'].fillna(house_clean.groupby('zipcode')['sqft_lot15'].transform('mean')),0)

# %%
#Remove Outliers for Bedrooms and Bathrooms
house_clean.loc[(house_clean.bedrooms == 0) & (house_clean.bedrooms > 10), 'bedrooms'] = np.nan
house_clean.loc[(house_clean.bathrooms == 0), 'bathrooms'] = np.nan

#Determining bedroom missing values by taking the mean of the bedrooms grouped by sqft_living
bins =  np.arange(start=250, stop=12100, step=1500)
ind = np.digitize(house_clean['sqft_living'], bins)
bed_mean = round(house_clean.groupby(ind)['bedrooms'].transform('mean').sort_index(),0)

house_clean['bedrooms'] = house_clean['bedrooms'].fillna(bed_mean)

#Determining bathroom missing values by taking the mean of bathrooms grouped by sqft_living
bath_mean = round(house_clean.groupby(ind)['bathrooms'].transform('mean').sort_index(),3)
house_clean['bathrooms'] = house_clean['bathrooms'].fillna(bath_mean)

# %%
house_clean.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
#Remove unneeded columns
house_clean.drop(columns=['floors', 'waterfront', 'view', 'sqft_above', 'sqft_basement', 'yr_renovated'], axis = 1, inplace = True)

# %%
#Visualization of pricing
#This scatterplot shows the lower range from minimum of 75,000 to 350,000.
sns.scatterplot(data=house_clean, x="long", y="lat", hue="price", hue_norm=(75000,350000), size = "price")
# Out:
# <AxesSubplot:xlabel='long', ylabel='lat'>

# %%
#This scatterplot shows the range from 350,000 to 550,000 with the median price being 450,000.
sns.scatterplot(data=house_clean, x="long", y="lat", hue="price", hue_norm=(350000,550000), size = "price")
# Out:
# <AxesSubplot:xlabel='long', ylabel='lat'>

# %%
#This scatterplot shows the range from 550,000 to MAX
sns.scatterplot(data=house_clean, x="long", y="lat", hue="price", hue_norm=(550000,7700000), size = "price")
# Out:
# <AxesSubplot:xlabel='long', ylabel='lat'>

# %%
#This bar chart shows pricing in relation to all transactions to show where the median lies easily.
fig = plt.figure()
plt.hist(house_clean['price'], bins=100, alpha=.5)
plt.xlabel('Price of House')
plt.ylabel('Number of Purchases')
plt.xlim(50000,1500000)
plt.title(r'Price for Houses Purchased in Kings County')
legend = ['Prices of Houses Purchased']
plt.legend(legend)
plt.show()

# %%
# Correlation between columns kept. There is a high correlation between price with sqft_living and grade.
corrMatrix = house_clean.corr()
plt.subplots(figsize=(12,12))
sns.heatmap(corrMatrix, annot=True, linewidths=2.5)
# Out:
# <AxesSubplot:>
